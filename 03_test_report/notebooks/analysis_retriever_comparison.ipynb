# %% [markdown]
# # 📊 Retriever Performance Comparison (N=5 Trials)
#
# 이 노트북은 **세 가지 리트리버(BM25, Vector, Hybrid)**의 성능을 **5회의 독립적인 시행**을 통해 비교 분석합니다.
#
# ### 🧪 실험 조건
# - **Dataset**: `golden_dataset.json` (총 3,000+개 중 무작위 추출)
# - **Trials**: 5회 반복 (각 시행마다 **동일한 50개 샘플**로 3개 모델 모두 테스트)
# - **Metrics**:
#   - **Hit@5**: 상위 5개 결과 내 정답 포함 여부
#   - **MRR**: Mean Reciprocal Rank (정답 순위의 효율성)
# - **Visualization**: Trial별 성능 변화 및 전체 평균 비교 차트

# %%
# ✅ Parameters
N_TRIALS = 5
SAMPLE_SIZE_PER_TRIAL = 50
K_VALUE = 5

# Setup
import sys
import os
from dotenv import load_dotenv
import pandas as pd
import numpy as np
import json
import random
import matplotlib.pyplot as plt
import seaborn as sns
import asyncio

project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(project_root)

load_dotenv(os.path.join(project_root, ".env"))
print(f"Project Root: {project_root}")

# 한글 폰트 설정 (Mac OS) - 그래프 깨짐 방지
plt.rcParams['font.family'] = 'AppleGothic'
plt.rcParams['axes.unicode_minus'] = False
# Out:
# Project Root: /Users/leemdo/Workspaces/SKN22-3rd-3Team

# %%
# Initialize Retrievers
from src.retrieval.bm25_retriever import BM25Retriever
from src.retrieval.vector_retriever import VectorRetriever
from src.retrieval.hybrid_search import HybridRetriever

print("🚀 Initializing Retrievers...")
bm25 = BM25Retriever(version="v3", collection_name="care_guides")
vector = VectorRetriever(version="v3", collection_name="care_guides")
hybrid = HybridRetriever(version="v3", collection_name="care_guides")
print("✅ All Retrievers Ready.")
# Out:
# 🚀 Initializing Retrievers...
# ✅ All Retrievers Ready.

# %%
# Load Dataset
dataset_path = os.path.join(project_root, "data/v3/golden_dataset.json")

if os.path.exists(dataset_path):
    with open(dataset_path, "r", encoding="utf-8") as f:
        FULL_DATASET = json.load(f)
    print(f"📚 Loaded {len(FULL_DATASET)} total cases.")
else:
    raise FileNotFoundError("Dataset not found!")
# Out:
# 📚 Loaded 3354 total cases.

# %%
# 🧪 Evaluation Function
async def evaluate(retriever, dataset, name, k=5):
    hits = 0
    reciprocal_ranks = 0
    
    for item in dataset:
        query = item.get("query")
        target = item.get("expected_keyword", item.get("target"))
        
        try:
            specialist = item.get("specialist")
            results = await retriever.search(query, specialist=specialist, limit=k)
        except Exception:
            results = []
            
        found_rank = None
        for rank, res in enumerate(results):
            content = (
                res.get('name_ko', '') + " " + 
                res.get('title_refined', '') + " " + 
                res.get('text', '')
            ).lower()
            
            if target.lower() in content:
                found_rank = rank + 1
                break
        
        if found_rank:
            hits += 1
            reciprocal_ranks += 1.0 / found_rank
            
    return {
        "Model": name,
        "Hit@5": hits / len(dataset),
        "MRR": reciprocal_ranks / len(dataset)
    }

# %%
# 🔄 Run Experiment Loop
results_log = []

print(f"🏁 Starting {N_TRIALS} Trials...")

for i in range(1, N_TRIALS + 1):
    print(f"\n[Trial {i}/{N_TRIALS}] Sampling Data...")
    
    # 1. Random Sampling (Same dataset for all models in this trial)
    trial_data = random.sample(FULL_DATASET, min(SAMPLE_SIZE_PER_TRIAL, len(FULL_DATASET)))
    
    # 2. Evaluate Models
    res_bm25 = await evaluate(bm25, trial_data, "BM25", k=K_VALUE)
    res_vector = await evaluate(vector, trial_data, "Vector", k=K_VALUE)
    res_hybrid = await evaluate(hybrid, trial_data, "Hybrid", k=K_VALUE)
    
    # 3. Log Results
    for res in [res_bm25, res_vector, res_hybrid]:
        res["Trial"] = i
        results_log.append(res)
        print(f"  > {res['Model']}: Hit@5={res['Hit@5']:.2f}, MRR={res['MRR']:.2f}")
        
df_results = pd.DataFrame(results_log)
# Out:
# 🏁 Starting 5 Trials...
#
# [Trial 1/5] Sampling Data...
# 🔍 [BM25 RETRIEVER]: '고양이 스트레스 해소 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 사료 선택 시 고려할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 구내염을 예방하는 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '차멀미 예방을 위한 팁은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 심리를 어떻게 알 수 있나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 합사 시 주의할 점은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '세상에서 가장 작은 고양이는 어떤 고양이인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '메인쿤의 특징은 무엇인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이를 혼자 두는 것은 괜찮을까?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 헤어볼이 자주 발생하는 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 보험 가입 시 주의할 점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이를 어떻게 도와줄 수 있나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 체중 관리는 어떻게 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 잠꼬대의 이유는 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 진드기 제거 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '어떤 스크래쳐가 좋나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '바르는 치약은 어떤가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 간식은 얼마나 주어야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 간식은 어떤 것이 좋나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '츄르는 어떤 간식인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '노령동물 관리 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 스크래쳐 추천은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 화장실 냄새는 왜 나는 건가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '헤어볼이란 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 귀여운 행동은 무엇인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 행동 대처법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '스킨쉽을 거부하는 고양이에게 어떻게 대처해야 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '귀여운 캣타워 추천해 주세요.' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 스트레스 해소 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 행동에서 불만을 어떻게 알 수 있나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 건강 상태를 어떻게 확인할까?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 유산균은 어떤 효과가 있나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '러시안 블루 고양이를 키울 때 주의할 점은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '딸꾹질이 지속되면 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '히말라야 고양이의 특징은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '어떤 부위를 마사지해야 할까?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 왜 자주 울까요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 안전한 식단은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 식단에 상추를 포함해도 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '러시안 블루는 어떤 고양이인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 행복 표현은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 소품을 고를 때 주의할 점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '스코티쉬 스트레이트의 유전 질환은 어떤 것이 있나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 행동을 이해하는 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 목욕 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 캣타워는 어떤 걸 사야 하나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 방광염의 증상은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '열사병 증상과 대처법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 기분이 안 좋을 때 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이를 어떻게 칭찬해야 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 스트레스 해소 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 사료 선택 시 고려할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 구내염을 예방하는 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '차멀미 예방을 위한 팁은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 심리를 어떻게 알 수 있나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 합사 시 주의할 점은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '세상에서 가장 작은 고양이는 어떤 고양이인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '메인쿤의 특징은 무엇인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이를 혼자 두는 것은 괜찮을까?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 헤어볼이 자주 발생하는 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 보험 가입 시 주의할 점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이를 어떻게 도와줄 수 있나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 체중 관리는 어떻게 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 잠꼬대의 이유는 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 진드기 제거 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '어떤 스크래쳐가 좋나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '바르는 치약은 어떤가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 간식은 얼마나 주어야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 간식은 어떤 것이 좋나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '츄르는 어떤 간식인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '노령동물 관리 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 스크래쳐 추천은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 화장실 냄새는 왜 나는 건가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '헤어볼이란 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 귀여운 행동은 무엇인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 행동 대처법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '스킨쉽을 거부하는 고양이에게 어떻게 대처해야 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '귀여운 캣타워 추천해 주세요.' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 스트레스 해소 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 행동에서 불만을 어떻게 알 수 있나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 건강 상태를 어떻게 확인할까?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 유산균은 어떤 효과가 있나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '러시안 블루 고양이를 키울 때 주의할 점은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '딸꾹질이 지속되면 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '히말라야 고양이의 특징은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '어떤 부위를 마사지해야 할까?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 왜 자주 울까요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 안전한 식단은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 식단에 상추를 포함해도 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '러시안 블루는 어떤 고양이인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 행복 표현은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 소품을 고를 때 주의할 점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '스코티쉬 스트레이트의 유전 질환은 어떤 것이 있나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 행동을 이해하는 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 목욕 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 캣타워는 어떤 걸 사야 하나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 방광염의 증상은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '열사병 증상과 대처법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 기분이 안 좋을 때 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이를 어떻게 칭찬해야 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 스트레스 해소 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 사료 선택 시 고려할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 구내염을 예방하는 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '차멀미 예방을 위한 팁은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 심리를 어떻게 알 수 있나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 합사 시 주의할 점은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '세상에서 가장 작은 고양이는 어떤 고양이인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '메인쿤의 특징은 무엇인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이를 혼자 두는 것은 괜찮을까?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 헤어볼이 자주 발생하는 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 보험 가입 시 주의할 점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이를 어떻게 도와줄 수 있나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 체중 관리는 어떻게 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 잠꼬대의 이유는 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 진드기 제거 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '어떤 스크래쳐가 좋나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '바르는 치약은 어떤가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 간식은 얼마나 주어야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 간식은 어떤 것이 좋나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '츄르는 어떤 간식인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '노령동물 관리 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 스크래쳐 추천은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 화장실 냄새는 왜 나는 건가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '헤어볼이란 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 귀여운 행동은 무엇인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 행동 대처법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '스킨쉽을 거부하는 고양이에게 어떻게 대처해야 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '귀여운 캣타워 추천해 주세요.' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 스트레스 해소 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 행동에서 불만을 어떻게 알 수 있나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 건강 상태를 어떻게 확인할까?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 유산균은 어떤 효과가 있나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '러시안 블루 고양이를 키울 때 주의할 점은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '딸꾹질이 지속되면 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '히말라야 고양이의 특징은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '어떤 부위를 마사지해야 할까?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 왜 자주 울까요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 안전한 식단은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 식단에 상추를 포함해도 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '러시안 블루는 어떤 고양이인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 행복 표현은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 소품을 고를 때 주의할 점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '스코티쉬 스트레이트의 유전 질환은 어떤 것이 있나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 행동을 이해하는 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 목욕 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 캣타워는 어떤 걸 사야 하나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 방광염의 증상은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '열사병 증상과 대처법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 기분이 안 좋을 때 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이를 어떻게 칭찬해야 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
#   > BM25: Hit@5=0.58, MRR=0.46
#   > Vector: Hit@5=0.46, MRR=0.39
#   > Hybrid: Hit@5=0.60, MRR=0.47
#
# [Trial 2/5] Sampling Data...
# 🔍 [BM25 RETRIEVER]: '식욕부진 시 어떻게 대처해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 스트레스를 줄이려면?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '봄에 고양이에게 주의해야 할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 간식은 얼마나 주어야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '숨숨집 사용법은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이는 집사 귀가 시간을 어떻게 아나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '코랏 고양이의 특징은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이에게 키위를 줘도 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 밤에 나를 쳐다보는 이유는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 낯가림을 어떻게 극복하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '비만 예방을 위해 어떤 조치를 취해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 전염병은 어떤 것이 있나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 스트레스의 원인은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 식욕 부진의 원인은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 손을 물면 왜 그런가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 응하고 우는 이유는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 수염 스트레스란 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 여드름은 왜 생기나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '어떤 환경에서 잘 자라나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 3건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 식탁에 오르는 이유는?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 캣닢을 좋아하는 이유는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '결막염 진단 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이에게 위험한 음식은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이에게 소시지를 주면 안 되는 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '멸치 급여 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 건강 신호는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '추천하는 낚시대는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 집사를 기다리는 이유는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 행동이 이상해요, 왜 그런가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 장난감 관리 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 독립 공간은 어떻게 만들어야 하나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 목욕은 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '흰 고양이를 키우면 어떤 점이 좋은가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '한국에서 인기 있는 고양이 품종은 무엇인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 체중 관리는 어떻게 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '반려동물 목욕 시 주의할 점은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이에게 바나나를 줘도 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 음수량은 얼마나 되어야 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 위험한 행동에 대한 대처 방법은 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이와의 관계를 어떻게 개선할 수 있을까?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 비듬 문제 해결법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '메인쿤의 특징은 무엇인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '냥냥펀치가 나쁜 행동인가?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 후각이 중요한 이유는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 무는 버릇은 왜 생기나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 파우치 추천은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 벤토나이트 모래의 종류는?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '중성화 수술 후 관리 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '펫보험이 필요한 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 선물을 주는 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '식욕부진 시 어떻게 대처해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 스트레스를 줄이려면?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '봄에 고양이에게 주의해야 할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 간식은 얼마나 주어야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '숨숨집 사용법은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이는 집사 귀가 시간을 어떻게 아나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '코랏 고양이의 특징은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이에게 키위를 줘도 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 밤에 나를 쳐다보는 이유는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 낯가림을 어떻게 극복하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '비만 예방을 위해 어떤 조치를 취해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 전염병은 어떤 것이 있나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 스트레스의 원인은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 식욕 부진의 원인은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 손을 물면 왜 그런가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 응하고 우는 이유는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 수염 스트레스란 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 여드름은 왜 생기나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '어떤 환경에서 잘 자라나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 식탁에 오르는 이유는?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 캣닢을 좋아하는 이유는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '결막염 진단 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이에게 위험한 음식은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이에게 소시지를 주면 안 되는 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '멸치 급여 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 건강 신호는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '추천하는 낚시대는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 집사를 기다리는 이유는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 행동이 이상해요, 왜 그런가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 장난감 관리 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 독립 공간은 어떻게 만들어야 하나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 목욕은 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '흰 고양이를 키우면 어떤 점이 좋은가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '한국에서 인기 있는 고양이 품종은 무엇인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 체중 관리는 어떻게 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '반려동물 목욕 시 주의할 점은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이에게 바나나를 줘도 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 음수량은 얼마나 되어야 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 위험한 행동에 대한 대처 방법은 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이와의 관계를 어떻게 개선할 수 있을까?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 비듬 문제 해결법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '메인쿤의 특징은 무엇인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '냥냥펀치가 나쁜 행동인가?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 후각이 중요한 이유는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 무는 버릇은 왜 생기나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 파우치 추천은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 벤토나이트 모래의 종류는?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '중성화 수술 후 관리 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '펫보험이 필요한 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 선물을 주는 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '식욕부진 시 어떻게 대처해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 스트레스를 줄이려면?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '봄에 고양이에게 주의해야 할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 간식은 얼마나 주어야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '숨숨집 사용법은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이는 집사 귀가 시간을 어떻게 아나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '코랏 고양이의 특징은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이에게 키위를 줘도 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 밤에 나를 쳐다보는 이유는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 낯가림을 어떻게 극복하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '비만 예방을 위해 어떤 조치를 취해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 전염병은 어떤 것이 있나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 스트레스의 원인은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 식욕 부진의 원인은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 손을 물면 왜 그런가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 응하고 우는 이유는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 수염 스트레스란 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 여드름은 왜 생기나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '어떤 환경에서 잘 자라나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 식탁에 오르는 이유는?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 캣닢을 좋아하는 이유는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '결막염 진단 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이에게 위험한 음식은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이에게 소시지를 주면 안 되는 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '멸치 급여 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 건강 신호는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '추천하는 낚시대는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 집사를 기다리는 이유는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 행동이 이상해요, 왜 그런가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 장난감 관리 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 독립 공간은 어떻게 만들어야 하나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 목욕은 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '흰 고양이를 키우면 어떤 점이 좋은가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '한국에서 인기 있는 고양이 품종은 무엇인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 체중 관리는 어떻게 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '반려동물 목욕 시 주의할 점은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이에게 바나나를 줘도 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 음수량은 얼마나 되어야 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 위험한 행동에 대한 대처 방법은 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이와의 관계를 어떻게 개선할 수 있을까?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 비듬 문제 해결법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '메인쿤의 특징은 무엇인가요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '냥냥펀치가 나쁜 행동인가?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 후각이 중요한 이유는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 무는 버릇은 왜 생기나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 파우치 추천은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 벤토나이트 모래의 종류는?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '중성화 수술 후 관리 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '펫보험이 필요한 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 선물을 주는 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
#   > BM25: Hit@5=0.70, MRR=0.55
#   > Vector: Hit@5=0.64, MRR=0.54
#   > Hybrid: Hit@5=0.74, MRR=0.65
#
# [Trial 3/5] Sampling Data...
# 🔍 [BM25 RETRIEVER]: '고양이와의 소통 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '대형 고양이 스크래쳐는 어떤 제품이 있나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이끼리 싸울 때 대처법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '양치 훈련은 언제 시작해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '픽시 밥의 유전 질환은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 입양 전 고려해야 할 점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '어떤 펫보험을 선택해야 하나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 건강을 어떻게 체크하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 질투를 느끼는 상황은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 혀의 구조는 어떻게 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '설날 음식 중 고양이가 먹으면 안 되는 것은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 아플 때 대처법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '키위를 어떻게 급여해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '아라비안 마우의 특징은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: 'Optimal Selection 키트의 특징은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '유산균 급여 시 주의사항은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '호흡기 질환에 좋은 제품은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '투병생활을 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '털 관리 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '각각의 성격 차이는 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 행동 언어는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 성격은 어떻게 형성되나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 입양 시 고려해야 할 점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '유전 질환에 대해 알아보려면?' 검색 중 (전문가: General Info, 필터: None)...
# ✅ [BM25 RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '털 관리 방법은?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 3건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 개구 호흡을 하면 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 끈 장난감을 좋아하는 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '원목 고양이 용품의 장점은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '어떤 해먹이 고양이에게 좋나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: 'FIP 치료 방법은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '근육 떨림이 나타날 때 어떻게 대처해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '안전한 식물은 어떤 것이 있나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '눈꺼풀 이상 증상은 어떤 것이 있나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '화이트톤 고양이 인테리어는 어떻게 해야 하나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '츄르는 사람도 먹어도 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '어떤 펫보험이 좋나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 실종 예방 방법은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '커피 중독 시 어떻게 대처해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '췌장염 관리에 필요한 식단은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '갓 태어난 고양이는 어떻게 돌보나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이와의 생활에서 얻는 이점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 혈액형의 종류는 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '편의점에서 길고양이 밥을 어떻게 챙길 수 있을까?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이와의 신뢰 관계를 어떻게 구축할까?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 중성화 수술이 필요한 이유는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 행동 특성은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 행동을 이해하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 행동을 이해하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 울음소리의 의미는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '양고기 급여 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이와의 소통 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '대형 고양이 스크래쳐는 어떤 제품이 있나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이끼리 싸울 때 대처법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '양치 훈련은 언제 시작해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '픽시 밥의 유전 질환은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 입양 전 고려해야 할 점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '어떤 펫보험을 선택해야 하나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 건강을 어떻게 체크하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 질투를 느끼는 상황은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 혀의 구조는 어떻게 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '설날 음식 중 고양이가 먹으면 안 되는 것은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 아플 때 대처법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '키위를 어떻게 급여해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '아라비안 마우의 특징은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: 'Optimal Selection 키트의 특징은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '유산균 급여 시 주의사항은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '호흡기 질환에 좋은 제품은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '투병생활을 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '털 관리 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '각각의 성격 차이는 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 행동 언어는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 성격은 어떻게 형성되나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 입양 시 고려해야 할 점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '유전 질환에 대해 알아보려면?' 검색 중 (전문가: General Info, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '털 관리 방법은?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 개구 호흡을 하면 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 끈 장난감을 좋아하는 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '원목 고양이 용품의 장점은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '어떤 해먹이 고양이에게 좋나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: 'FIP 치료 방법은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '근육 떨림이 나타날 때 어떻게 대처해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '안전한 식물은 어떤 것이 있나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '눈꺼풀 이상 증상은 어떤 것이 있나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '화이트톤 고양이 인테리어는 어떻게 해야 하나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '츄르는 사람도 먹어도 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '어떤 펫보험이 좋나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 실종 예방 방법은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '커피 중독 시 어떻게 대처해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '췌장염 관리에 필요한 식단은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '갓 태어난 고양이는 어떻게 돌보나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이와의 생활에서 얻는 이점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 혈액형의 종류는 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '편의점에서 길고양이 밥을 어떻게 챙길 수 있을까?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이와의 신뢰 관계를 어떻게 구축할까?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 중성화 수술이 필요한 이유는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 행동 특성은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 행동을 이해하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 행동을 이해하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 울음소리의 의미는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '양고기 급여 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이와의 소통 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '대형 고양이 스크래쳐는 어떤 제품이 있나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이끼리 싸울 때 대처법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '양치 훈련은 언제 시작해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '픽시 밥의 유전 질환은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 입양 전 고려해야 할 점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '어떤 펫보험을 선택해야 하나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 건강을 어떻게 체크하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 질투를 느끼는 상황은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 혀의 구조는 어떻게 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '설날 음식 중 고양이가 먹으면 안 되는 것은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 아플 때 대처법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '키위를 어떻게 급여해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '아라비안 마우의 특징은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: 'Optimal Selection 키트의 특징은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '유산균 급여 시 주의사항은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '호흡기 질환에 좋은 제품은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '투병생활을 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '털 관리 시 주의할 점은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '각각의 성격 차이는 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 행동 언어는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 성격은 어떻게 형성되나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 입양 시 고려해야 할 점은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '유전 질환에 대해 알아보려면?' 검색 중 (전문가: General Info, 필터: None)...
# ✅ [RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '털 관리 방법은?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 개구 호흡을 하면 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 끈 장난감을 좋아하는 이유는?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '원목 고양이 용품의 장점은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '어떤 해먹이 고양이에게 좋나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: 'FIP 치료 방법은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '근육 떨림이 나타날 때 어떻게 대처해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '안전한 식물은 어떤 것이 있나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '눈꺼풀 이상 증상은 어떤 것이 있나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '화이트톤 고양이 인테리어는 어떻게 해야 하나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '츄르는 사람도 먹어도 되나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '어떤 펫보험이 좋나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# ...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 이물질을 먹었을 때 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 만세 자세는 왜 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 암의 치료 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '털 없는 고양이를 어떻게 관리하나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 딸꾹질 대처법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이와 놀아줄 때 주의할 점은 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '세이오앙 벤토나이트 모래는 어떤가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '페르시안 친칠라의 특징은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이와 강아지의 지능 차이는?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 행동을 이해하는 방법은 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '유기동물 입양 절차는 어떻게 되나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 신체 능력은 어떤 것이 있나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 감정을 이해하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 가방에 들어가는 이유는 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 화장실 관리 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '한국과 외국의 고양이 천적 차이는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 눈병의 종류는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '헤어볼 예방을 위한 추천 제품은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 행동에서 서열을 어떻게 알 수 있나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '발정기 증상은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 왜 어깨에 올라타나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 똥 딱지는 왜 생기나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 행동을 이해하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 과일 섭취 방법은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 수반은 어떤 제품이 좋나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [BM25 RETRIEVER]: 4건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 배변 횟수는 몇 번이 정상인가?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 소변 냄새를 어떻게 없애나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이의 행동을 이해하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '원목 고양이 용품의 장점은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '어떤 유전 질환이 반려동물에게 흔한가?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '어떤 캣휠을 추천하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 여드름 치료 방법은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '스크래쳐에 흥미를 끌려면 어떻게 해야 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 건강 관리의 중요성은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '응고력이 좋은 모래는?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '노르웨이 숲 고양이의 역사에 대해 알고 싶어요.' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '벤토나이트 모래의 장점은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이가 배를 보이는 이유는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 감기를 예방하는 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이를 방해하지 말아야 할 순간은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '토이거 고양이는 어떤 성격을 가지고 있나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '사막화를 예방하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '어떤 유산균이 안전한가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [BM25 RETRIEVER]: '고양이 화장실 관리 방법은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [BM25 RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '페르시안 고양이와 터키쉬 앙고라의 차이는?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 엉덩이를 보여주는 이유는 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이와의 놀이 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '픽시 밥은 어떤 성격인가?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 행동 심리는?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 좋아하는 잠자리 특징은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 이물질을 먹었을 때 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 만세 자세는 왜 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 암의 치료 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '털 없는 고양이를 어떻게 관리하나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 딸꾹질 대처법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이와 놀아줄 때 주의할 점은 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '세이오앙 벤토나이트 모래는 어떤가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '페르시안 친칠라의 특징은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이와 강아지의 지능 차이는?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 행동을 이해하는 방법은 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '유기동물 입양 절차는 어떻게 되나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 신체 능력은 어떤 것이 있나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 감정을 이해하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 가방에 들어가는 이유는 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 화장실 관리 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '한국과 외국의 고양이 천적 차이는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 눈병의 종류는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '헤어볼 예방을 위한 추천 제품은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 행동에서 서열을 어떻게 알 수 있나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '발정기 증상은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 왜 어깨에 올라타나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 똥 딱지는 왜 생기나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 행동을 이해하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 과일 섭취 방법은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 수반은 어떤 제품이 좋나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 0건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 배변 횟수는 몇 번이 정상인가?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 소변 냄새를 어떻게 없애나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이의 행동을 이해하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '원목 고양이 용품의 장점은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '어떤 유전 질환이 반려동물에게 흔한가?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '어떤 캣휠을 추천하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 여드름 치료 방법은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '스크래쳐에 흥미를 끌려면 어떻게 해야 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 건강 관리의 중요성은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '응고력이 좋은 모래는?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '노르웨이 숲 고양이의 역사에 대해 알고 싶어요.' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '벤토나이트 모래의 장점은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이가 배를 보이는 이유는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 감기를 예방하는 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이를 방해하지 말아야 할 순간은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '토이거 고양이는 어떤 성격을 가지고 있나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '사막화를 예방하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '어떤 유산균이 안전한가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [VECTOR RETRIEVER]: '고양이 화장실 관리 방법은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [VECTOR RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '페르시안 고양이와 터키쉬 앙고라의 차이는?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 엉덩이를 보여주는 이유는 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이와의 놀이 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '픽시 밥은 어떤 성격인가?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 행동 심리는?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 좋아하는 잠자리 특징은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 이물질을 먹었을 때 어떻게 해야 하나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 만세 자세는 왜 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 암의 치료 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '털 없는 고양이를 어떻게 관리하나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 딸꾹질 대처법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이와 놀아줄 때 주의할 점은 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '세이오앙 벤토나이트 모래는 어떤가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '페르시안 친칠라의 특징은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이와 강아지의 지능 차이는?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 행동을 이해하는 방법은 무엇인가요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '유기동물 입양 절차는 어떻게 되나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 신체 능력은 어떤 것이 있나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 감정을 이해하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 가방에 들어가는 이유는 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 화장실 관리 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '한국과 외국의 고양이 천적 차이는?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 눈병의 종류는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '헤어볼 예방을 위한 추천 제품은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 행동에서 서열을 어떻게 알 수 있나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '발정기 증상은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 왜 어깨에 올라타나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 똥 딱지는 왜 생기나요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 행동을 이해하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 과일 섭취 방법은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 수반은 어떤 제품이 좋나요?' 검색 중 (전문가: General, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 배변 횟수는 몇 번이 정상인가?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 소변 냄새를 어떻게 없애나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이의 행동을 이해하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '원목 고양이 용품의 장점은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '어떤 유전 질환이 반려동물에게 흔한가?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '어떤 캣휠을 추천하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 여드름 치료 방법은 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '스크래쳐에 흥미를 끌려면 어떻게 해야 하나요?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 건강 관리의 중요성은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '응고력이 좋은 모래는?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '노르웨이 숲 고양이의 역사에 대해 알고 싶어요.' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '벤토나이트 모래의 장점은 무엇인가요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이가 배를 보이는 이유는 무엇인가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 감기를 예방하는 방법은?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이를 방해하지 말아야 할 순간은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '토이거 고양이는 어떤 성격을 가지고 있나요?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '사막화를 예방하는 방법은?' 검색 중 (전문가: Peacekeeper, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '어떤 유산균이 안전한가요?' 검색 중 (전문가: Physician, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# 🔍 [RETRIEVER]: '고양이 화장실 관리 방법은?' 검색 중 (전문가: Liaison, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
#   > BM25: Hit@5=0.70, MRR=0.64
#   > Vector: Hit@5=0.66, MRR=0.53
#   > Hybrid: Hit@5=0.78, MRR=0.65

# %% [markdown]
# ## 📊 Visualization

# %%
# Aggregated Stats
summary = df_results.groupby("Model")[["Hit@5", "MRR"]].agg(["mean", "std"])
display(summary)

# Plotting
fig, axes = plt.subplots(1, 2, figsize=(15, 6))

# 1. Hit@5 Comparison
sns.barplot(data=df_results, x="Model", y="Hit@5", ax=axes[0], palette="viridis", errorbar="sd")
axes[0].set_title("Hit@5 Score Comparison (Mean ± SD)")
axes[0].set_ylim(0, 1.0)
for p in axes[0].patches:
    axes[0].annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'bottom', xytext = (0, 5), textcoords = 'offset points')

# 2. MRR Comparison
sns.barplot(data=df_results, x="Model", y="MRR", ax=axes[1], palette="magma", errorbar="sd")
axes[1].set_title("MRR Score Comparison (Mean ± SD)")
axes[1].set_ylim(0, 1.0)
for p in axes[1].patches:
    axes[1].annotate(f'{p.get_height():.2f}', (p.get_x() + p.get_width() / 2., p.get_height()), 
                     ha = 'center', va = 'bottom', xytext = (0, 5), textcoords = 'offset points')

plt.tight_layout()
plt.show()
# Out:
#         Hit@5                 MRR
#          mean       std      mean       std
# Model
# BM25    0.676  0.060663  0.559533  0.066939
# Hybrid  0.728  0.072938  0.606667  0.079235
# Vector  0.576  0.080498  0.486200  0.057593
# /var/folders/n6/9fr973913k7931ymsg4ly6rc0000gn/T/ipykernel_22003/4107645841.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_results, x="Model", y="Hit@5", ax=axes[0], palette="viridis", errorbar="sd")
# /var/folders/n6/9fr973913k7931ymsg4ly6rc0000gn/T/ipykernel_22003/4107645841.py:17: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(data=df_results, x="Model", y="MRR", ax=axes[1], palette="magma", errorbar="sd")

# %%
# Trial-wise Line Plot (Consistency Check)
fig, ax = plt.subplots(figsize=(12, 6))
sns.lineplot(data=df_results, x="Trial", y="MRR", hue="Model", marker="o", ax=ax)
ax.set_title("MRR Stability Across 5 Trials")
ax.set_ylim(0, 1.0)
ax.set_xticks(range(1, N_TRIALS + 1))
plt.grid(True, linestyle="--", alpha=0.5)
plt.show()
