# %% [markdown]
# # 🧑‍⚖️ LLM-as-a-judge: Advanced Retrieval Evaluation
#
# 이 노트북은 단순 키워드 매칭(Hit@k)을 넘어, **LLM(GPT-4o)**을 사용하여 리트리버의 실제 성능을 정성적으로 평가합니다.
#
# ### 🚀 주요 프로세스
# 1.  **Hard Query Augmentation**: 기존의 단순한 질문을 실제 유저들이 할 법한 모호하고 복잡한 질문으로 변환합니다.
# 2.  **Hybrid Retrieval**: 변환된 질문으로 검색을 수행합니다.
# 3.  **LLM Scoring**: 검색 결과가 질문의 의도에 얼마나 부합하는지 1~5점 척도로 채점합니다.

# %%
# ✅ 실험 파라미터
SAMPLE_SIZE = 10        # 비용 문제로 적은 샘플로 시작 권장
JUDGE_MODEL = "gpt-4o"  # 평가자 모델
RETRIEVER_K = 5         # 검색할 문서 수

# 환경 설정
import sys
import os
from dotenv import load_dotenv
import pandas as pd
import json
import random
import asyncio
from typing import List, Optional
from pydantic import BaseModel, Field

# LangChain
from langchain.chat_models import init_chat_model
from src.core.config import LLMConfig
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import PydanticOutputParser

project_root = os.path.abspath(os.path.join(os.getcwd(), "../.."))
sys.path.append(project_root)

load_dotenv(os.path.join(project_root, ".env"))
print(f"Project Root: {project_root}")
# Out:
# Project Root: /Users/leemdo/Workspaces/SKN22-3rd-3Team

# %%
# Initialize Components
from src.retrieval.hybrid_search import HybridRetriever

retriever = HybridRetriever(version="v3", collection_name="care_guides")
llm_judge = init_chat_model(JUDGE_MODEL, model_provider="openai", temperature=0)

print("✅ Components Initialized.")
# Out:
# ✅ Components Initialized.

# %% [markdown]
# ## 1. 데이터셋 로드 및 샘플링

# %%
dataset_path = os.path.join(project_root, "data/v3/golden_dataset.json")

if os.path.exists(dataset_path):
    with open(dataset_path, "r", encoding="utf-8") as f:
        FULL_DATASET = json.load(f)
    print(f"📚 Loaded {len(FULL_DATASET)} test cases.")
else:
    print("⚠️ Dataset not found. Using mock.")
    FULL_DATASET = [{"query": "메인쿤 특징", "expected_keyword": "메인 쿤"}]

test_dataset = random.sample(FULL_DATASET, min(SAMPLE_SIZE, len(FULL_DATASET)))
print(f"🧪 Selected {len(test_dataset)} samples for evaluation.")
# Out:
# 📚 Loaded 3354 test cases.
# 🧪 Selected 10 samples for evaluation.

# %% [markdown]
# ## 2. Hard Query Generation (Augmentation)
# 단순한 키워드형 질문을 문맥이 포함된 복합 질문으로 변환합니다.
# - **Before**: "메인쿤 특징"
# - **After**: "덩치가 크고 털이 풍성한 고양이를 키우고 싶은데, 성격이 강아지처럼 온순한 품종이 뭐가 있을까?"

# %%
class AugmentedQuery(BaseModel):
    hard_query: str = Field(..., description="The transformed complex query")

augment_prompt = ChatPromptTemplate.from_messages([
    ("system", "You are a creative user helper. Convert the given simple query into a more natural, complex, and slightly ambiguous user question that maintains the original intent but is harder for a keyword search engine to match. Do NOT include the specific target keyword if possible, describe its characteristics instead."),
    ("human", "Original Query: {query}\nTarget Keyword: {target}")
])

augment_chain = augment_prompt | llm_judge.with_structured_output(AugmentedQuery)

async def generate_hard_queries(dataset):
    augmented_dataset = []
    print("🚀 Generating Hard Queries...")
    
    for item in dataset:
        original_query = item.get("query")
        target = item.get("expected_keyword", item.get("target"))
        
        try:
            res = await augment_chain.ainvoke({"query": original_query, "target": target})
            augmented_dataset.append({
                "original_query": original_query,
                "hard_query": res.hard_query,
                "target": target
            })
            print(f" - {original_query} -> {res.hard_query}")
        except Exception as e:
            print(f"❌ Error generating query for {original_query}: {e}")
            
    return augmented_dataset

# 실행
augmented_data = await generate_hard_queries(test_dataset)
# Out:
# 🚀 Generating Hard Queries...
#  - 고양이 방광염의 증상은? -> When it comes to our feline friends, what are some of the telltale signs that might suggest they're dealing with a common urinary issue, and how does this condition rank among other prevalent health concerns for them?
#  - 고양이 병원에 가기 전에 알아야 할 점은? -> When considering a visit to a place where feline companions receive medical care, what are some crucial aspects one should be aware of to ensure the choice is optimal and the experience is beneficial for both the pet and the owner?
#  - 고양이의 심리를 이해하는 방법은 무엇인가요? -> 고양이들이 가끔 보여주는 그 특유의 행동, 마치 잘못을 깨달은 듯한 모습이 진짜로 그들의 마음을 반영하는 걸까요? 그들의 내면 세계를 조금 더 깊이 들여다보고 싶다면, 어떤 접근법이 필요할까요?
#  - 고양이의 매력 포인트는? -> What are some of the endearing qualities that make these furry companions so beloved by many, and why do they hold such a special place in people's hearts?
#  - 정수기 고르는 방법은? -> When considering the best hydration station for our feline friends, what are the key factors one should weigh to ensure both functionality and appeal to our whiskered companions?
#  - 고양이 분유는 어떻게 급여하나요? -> When it comes to feeding a young feline with a special powdered nourishment, what are the best practices and considerations one should keep in mind to ensure the little one thrives?
#  - 어떤 간식을 추천하나요? -> 작고 귀여운 털뭉치가 처음으로 맛볼 수 있는 특별한 먹거리는 무엇이 있을까요? 그리고 이 작은 친구에게 언제쯤 그 특별한 간식을 주는 것이 좋을까요?
#  - 고양이 혀의 구조는 어떻게 되나요? -> 고양이의 입 안에 있는 그 독특한 부분, 특히 그 표면이 마치 작은 돌기들로 덮인 것처럼 느껴지는 부분에 대해 설명해 줄 수 있나요? 그 부분이 어떻게 생겼고, 왜 그런 느낌을 주는지 궁금합니다.
#  - 고양이 여드름 치료 방법은 무엇인가요? -> 제가 반려묘의 피부에 작은 돌기들이 생긴 걸 발견했는데, 이게 흔히 있는 문제인지, 그리고 어떻게 하면 이 상황을 개선할 수 있을지 궁금합니다. 혹시 이런 경우에 도움이 될 만한 조언이나 경험이 있으신가요?
#  - 고양이의 우울증 원인은? -> What are some behaviors or actions that might inadvertently dampen the spirits of our feline companions, potentially leading to a decline in their usual playful demeanor?

# %% [markdown]
# ## 3. Retrieval & LLM Evaluation
# 생성된 Hard Query로 검색을 수행하고, 결과를 LLM이 채점합니다.

# %%
# 평가 결과 모델
class JudgeResult(BaseModel):
    score: int = Field(..., description="Score from 1 to 5")
    reasoning: str = Field(..., description="Reasoning for the score")

# 평가 프롬프트
judge_prompt = ChatPromptTemplate.from_messages([
    ("system", """You are an expert search relevance evaluator.
Apply the following score rubric to the retrieved documents for the user query:

Score 5: The document provides a perfect answer to the user's implicit and explicit intent. It contains the core semantic meaning or the specific target entity described.
Score 4: The document is very relevant and helpful, but might contain slight noise or misses a minor detail.
Score 3: The document is somewhat relevant (mentions related concepts), but does not directly answer the core intent or is too broad.
Score 2: The document has very low relevance (perhaps shares a keyword) but does not help the user.
Score 1: The document is completely irrelevant.

User Query: {query}
Expected Topic/Target: {target}

Retrieved Documents:
{context}
"""),
])

judge_chain = judge_prompt | llm_judge.with_structured_output(JudgeResult)

# ==================================================================================
# 🔄 RAG Context Distillation (Same with Agent Logic)
# ----------------------------------------------------------------------------------
# 실제 에이전트(Care Team, Liaison)와 완전히 동일한 로직으로 문맥을 압축합니다.
# ==================================================================================
from langchain_core.messages import SystemMessage

llm_distill = init_chat_model(LLMConfig.ROUTER_MODEL, model_provider="openai", temperature=0)

async def distill_context(query, docs):
    if not docs:
        return ""
    
    # 1. 문서 블록 구성 (Agent와 동일 포맷)
    docs_block = "\n\n".join([
        f"[{r.get('title_refined', '') or r.get('title', '')}]\n{r.get('text', '')[:1500]}"
        for r in docs
    ])
    
    # 2. LLM 호출 (Agent와 동일 프롬프트 구조 - 단일 SystemMessage)
    messages = [
        SystemMessage(content=(
            "아래 참고 문서들에서 사용자 질문에 답하는 데 필요한 핵심 정보만 간결하게 추출하세요.\n"
            "- 불필요한 서론/반복 제거, 핵심 팩트와 수치 위주로 정리\n"
            "- 3~5개 bullet point, 총 300자 이내\n\n"
            f"[사용자 질문]\n{query}\n\n"
            f"[참고 문서]\n{docs_block}"
        ))
    ]
    
    try:
        res = await llm_distill.ainvoke(messages)
        return res.content
    except Exception as e:
        print(f"Error distilling context: {e}")
        return ""

async def run_llm_judge(aug_data):
    results = []
    print("\n⚖️ Starting LLM Evaluation...")
    
    for item in aug_data:
        query = item['hard_query']
        target = item['target']
        
        # 1. 검색
        # Specialist는 None으로 가정 (Hard Query라서 분류 어려울 수 있음)
        docs = await retriever.search(query, limit=RETRIEVER_K)
        
        # 2. Context 구성 (Distillation 적용)
        context_text = await distill_context(query, docs)
        
        # 3. 평가
        try:
            eval_res = await judge_chain.ainvoke({
                "query": query, 
                "target": target,
                "context": context_text
            })
            
            results.append({
                "Original": item['original_query'],
                "Hard_Query": query,
                "Score": eval_res.score,
                "Reasoning": eval_res.reasoning,
                "Top1_Doc": docs[0].get('title', 'No Result') if docs else 'None'
            })
            print(f"User: {query[:30]}... | Score: {eval_res.score}/5")
            
        except Exception as e:
            print(f"Error evaluating {query}: {e}")
            
    return pd.DataFrame(results)

# 평가 실행
df_eval = await run_llm_judge(augmented_data)
# Out:
# ⚖️ Starting LLM Evaluation...
# 🔍 [RETRIEVER]: 'When it comes to our feline friends, what are some of the telltale signs that might suggest they're dealing with a common urinary issue, and how does this condition rank among other prevalent health concerns for them?' 검색 중 (전문가: None, 필터: None)...
# 키워드 검색 실패: "text.query" cannot be empty, full error: {'ok': 0.0, 'errmsg': '"text.query" cannot be empty', 'code': 8, 'codeName': 'UnknownError', '$clusterTime': {'clusterTime': Timestamp(1770032938, 1), 'signature': {'hash': b'f\xdc\xe0\xccb\x86\xa5\xfd\x99\xaa\x97H\xdf\x0f\x8aA1\xca\xf4\xc1', 'keyId': 7558147511785881602}}, 'operationTime': Timestamp(1770032938, 1)}
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# User: When it comes to our feline fr... | Score: 5/5
# 🔍 [RETRIEVER]: 'When considering a visit to a place where feline companions receive medical care, what are some crucial aspects one should be aware of to ensure the choice is optimal and the experience is beneficial for both the pet and the owner?' 검색 중 (전문가: None, 필터: None)...
# 키워드 검색 실패: "text.query" cannot be empty, full error: {'ok': 0.0, 'errmsg': '"text.query" cannot be empty', 'code': 8, 'codeName': 'UnknownError', '$clusterTime': {'clusterTime': Timestamp(1770032948, 1), 'signature': {'hash': b'\xec\xe8F\x17\xc6+0D\x8e\x82i\xd0\xeb\x92\xcd\xbc\xf9\xf9\xf5\x1b', 'keyId': 7558147511785881602}}, 'operationTime': Timestamp(1770032948, 1)}
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# User: When considering a visit to a ... | Score: 5/5
# 🔍 [RETRIEVER]: '고양이들이 가끔 보여주는 그 특유의 행동, 마치 잘못을 깨달은 듯한 모습이 진짜로 그들의 마음을 반영하는 걸까요? 그들의 내면 세계를 조금 더 깊이 들여다보고 싶다면, 어떤 접근법이 필요할까요?' 검색 중 (전문가: None, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# User: 고양이들이 가끔 보여주는 그 특유의 행동, 마치 잘못을... | Score: 4/5
# 🔍 [RETRIEVER]: 'What are some of the endearing qualities that make these furry companions so beloved by many, and why do they hold such a special place in people's hearts?' 검색 중 (전문가: None, 필터: None)...
# 키워드 검색 실패: "text.query" cannot be empty, full error: {'ok': 0.0, 'errmsg': '"text.query" cannot be empty', 'code': 8, 'codeName': 'UnknownError', '$clusterTime': {'clusterTime': Timestamp(1770032969, 1), 'signature': {'hash': b'\xe5\xd9g\x8dN|l\xc2=\x14\xae\r\xb3f\xc7\x91\x80\xde\xbdD', 'keyId': 7558147511785881602}}, 'operationTime': Timestamp(1770032969, 1)}
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# User: What are some of the endearing... | Score: 5/5
# 🔍 [RETRIEVER]: 'When considering the best hydration station for our feline friends, what are the key factors one should weigh to ensure both functionality and appeal to our whiskered companions?' 검색 중 (전문가: None, 필터: None)...
# 키워드 검색 실패: "text.query" cannot be empty, full error: {'ok': 0.0, 'errmsg': '"text.query" cannot be empty', 'code': 8, 'codeName': 'UnknownError', '$clusterTime': {'clusterTime': Timestamp(1770032976, 1), 'signature': {'hash': b'\xf6\xc5M==p\xac;\xfe\x01tk\x89\x86\x8bu\x06#\x99\xaf', 'keyId': 7558147511785881602}}, 'operationTime': Timestamp(1770032976, 1)}
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# User: When considering the best hydr... | Score: 1/5
# 🔍 [RETRIEVER]: 'When it comes to feeding a young feline with a special powdered nourishment, what are the best practices and considerations one should keep in mind to ensure the little one thrives?' 검색 중 (전문가: None, 필터: None)...
# 키워드 검색 실패: "text.query" cannot be empty, full error: {'ok': 0.0, 'errmsg': '"text.query" cannot be empty', 'code': 8, 'codeName': 'UnknownError', '$clusterTime': {'clusterTime': Timestamp(1770032987, 1), 'signature': {'hash': b'tc\\\xe12\x93;\x9c\xe0|\x04\x0c\x03\xb1-k\xc3v\x8e\xca', 'keyId': 7558147511785881602}}, 'operationTime': Timestamp(1770032987, 1)}
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# User: When it comes to feeding a you... | Score: 1/5
# 🔍 [RETRIEVER]: '작고 귀여운 털뭉치가 처음으로 맛볼 수 있는 특별한 먹거리는 무엇이 있을까요? 그리고 이 작은 친구에게 언제쯤 그 특별한 간식을 주는 것이 좋을까요?' 검색 중 (전문가: None, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# User: 작고 귀여운 털뭉치가 처음으로 맛볼 수 있는 특별한 먹... | Score: 5/5
# 🔍 [RETRIEVER]: '고양이의 입 안에 있는 그 독특한 부분, 특히 그 표면이 마치 작은 돌기들로 덮인 것처럼 느껴지는 부분에 대해 설명해 줄 수 있나요? 그 부분이 어떻게 생겼고, 왜 그런 느낌을 주는지 궁금합니다.' 검색 중 (전문가: None, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# User: 고양이의 입 안에 있는 그 독특한 부분, 특히 그 표면... | Score: 5/5
# 🔍 [RETRIEVER]: '제가 반려묘의 피부에 작은 돌기들이 생긴 걸 발견했는데, 이게 흔히 있는 문제인지, 그리고 어떻게 하면 이 상황을 개선할 수 있을지 궁금합니다. 혹시 이런 경우에 도움이 될 만한 조언이나 경험이 있으신가요?' 검색 중 (전문가: None, 필터: None)...
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# User: 제가 반려묘의 피부에 작은 돌기들이 생긴 걸 발견했는데... | Score: 4/5
# 🔍 [RETRIEVER]: 'What are some behaviors or actions that might inadvertently dampen the spirits of our feline companions, potentially leading to a decline in their usual playful demeanor?' 검색 중 (전문가: None, 필터: None)...
# 키워드 검색 실패: "text.query" cannot be empty, full error: {'ok': 0.0, 'errmsg': '"text.query" cannot be empty', 'code': 8, 'codeName': 'UnknownError', '$clusterTime': {'clusterTime': Timestamp(1770033030, 1), 'signature': {'hash': b'\xad-\xc4A\xffC\x99i/*R\x86\x15\\i\x9f\xdf\xb5\xf3\x0c', 'keyId': 7558147511785881602}}, 'operationTime': Timestamp(1770033030, 1)}
# ✅ [RETRIEVER]: 5건의 결과를 찾았습니다.
# User: What are some behaviors or act... | Score: 4/5

# %%
# 결과 분석
print("="*40)
print(f"🏆 Average Score: {df_eval['Score'].mean():.2f} / 5.0")
print("="*40)
display(df_eval)
# Out:
# ========================================
# 🏆 Average Score: 3.90 / 5.0
# ========================================
#                    Original  \
# 0             고양이 방광염의 증상은?
# 1   고양이 병원에 가기 전에 알아야 할 점은?
# 2  고양이의 심리를 이해하는 방법은 무엇인가요?
# 3             고양이의 매력 포인트는?
# 4              정수기 고르는 방법은?
# 5        고양이 분유는 어떻게 급여하나요?
# 6             어떤 간식을 추천하나요?
# 7       고양이 혀의 구조는 어떻게 되나요?
# 8     고양이 여드름 치료 방법은 무엇인가요?
# 9             고양이의 우울증 원인은?
#
#                                           Hard_Query  Score  \
# 0  When it comes to our feline friends, what are ...      5
# 1  When considering a visit to a place where feli...      5
# 2  고양이들이 가끔 보여주는 그 특유의 행동, 마치 잘못을 깨달은 듯한 모습이 진짜로 ...      4
# 3  What are some of the endearing qualities that ...      5
# 4  When considering the best hydration station fo...      1
# 5  When it comes to feeding a young feline with a...      1
# 6  작고 귀여운 털뭉치가 처음으로 맛볼 수 있는 특별한 먹거리는 무엇이 있을까요? 그리...      5
# 7  고양이의 입 안에 있는 그 독특한 부분, 특히 그 표면이 마치 작은 돌기들로 덮인 ...      5
# 8  제가 반려묘의 피부에 작은 돌기들이 생긴 걸 발견했는데, 이게 흔히 있는 문제인지,...      4
# 9  What are some behaviors or actions that might ...      4
#
#                                            Reasoning   Top1_Doc
# 0  The retrieved documents provide a comprehensiv...  No Result
# 1  The retrieved documents collectively provide c...  No Result
# 2  The document is very relevant to the user's qu...  No Result
# 3  The retrieved documents collectively provide a...  No Result
# 4  The retrieved documents are completely irrelev...  No Result
# 5  The retrieved documents focus on general cat f...  No Result
# 6  The document provides a perfect answer to the ...  No Result
# 7  The document provides a detailed explanation o...  No Result
# 8  The document is very relevant to the user's qu...  No Result
# 9  The document lists behaviors that can upset a ...  No Result
